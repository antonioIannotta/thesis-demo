# %%
import pandas as pd
from proxy.proxy_detection import return_association_results

# %%
dataset = pd.read_excel('./dataset/default of credit card clients.xls')

# %%
dataset
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3
# 0          1      20000    2          2         1   24      2      2     -1  \
# 1          2     120000    2          2         2   26     -1      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
# ...

# %%
res = return_association_results(dataset)

# %%
for i in res:
    print(i)
# Out:
# RelationRecord(items=frozenset({'4', '3'}), support=0.011333333333333334, ordered_statistics=[OrderedStatistic(items_base=frozenset({'4'}), items_add=frozenset({'3'}), confidence=0.6284658040665435, lift=3.103534834896511)])
# RelationRecord(items=frozenset({'390', '780'}), support=0.010633333333333333, ordered_statistics=[OrderedStatistic(items_base=frozenset({'780'}), items_add=frozenset({'390'}), confidence=0.6354581673306773, lift=27.95270530780105)])
# RelationRecord(items=frozenset({'390', '-1', '780'}), support=0.0099, ordered_statistics=[OrderedStatistic(items_base=frozenset({'780'}), items_add=frozenset({'390', '-1'}), confidence=0.5916334661354582, lift=29.532452552518713), OrderedStatistic(items_base=frozenset({'-1', '780'}), items_add=frozenset({'390'}), confidence=0.6988235294117648, lift=30.740037950664142)])
# ...
